# %%
# %pip install --upgrade transformers torch pandas scikit-learn
# %pip install ipywidgets 
# %pip install ipykernel --update-deps --force-reinstall
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# Usage:
#   /usr/local/opt/python@3.11/bin/python3.11 -m pip install [options] <requirement specifier> [package-index-options] ...
#   /usr/local/opt/python@3.11/bin/python3.11 -m pip install [options] -r <requirements file> [package-index-options] ...
#   /usr/local/opt/python@3.11/bin/python3.11 -m pip install [options] [-e] <vcs project url> ...
#   /usr/local/opt/python@3.11/bin/python3.11 -m pip install [options] [-e] <local project path> ...
#   /usr/local/opt/python@3.11/bin/python3.11 -m pip install [options] <archive url/path> ...
#
# no such option: --update-deps
# ...

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from sklearn.metrics import classification_report

#load the Hate-speech-CNERG model and tokenizer
model_name = "Hate-speech-CNERG/dehatebert-mono-english"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

#load the CSV files
youtube_comments_df = pd.read_csv("/Users/siva/Downloads/kaggle_datasets/youtube_comments.csv")
reddit_comments_df = pd.read_csv("/Users/siva/Downloads/kaggle_datasets/combined_reddit_data.csv")

#define batch size for processing and saving
BATCH_SIZE = 1000  # Adjust this based on memory capacity

#define a function to tokenize and predict for a batch of comments
def predict_in_batches(df, text_column, output_path):
    #create an empty list to hold results
    results = []

    for i in range(0, len(df), BATCH_SIZE):
        batch_df = df.iloc[i:i+BATCH_SIZE]
        
        #tokenize the text for the current batch
        encoded_inputs = tokenizer(
            batch_df[text_column].tolist(),
            max_length=128,
            truncation=True,
            padding=True,
            return_tensors='pt'
        )
        
        #run the model to create predictions
        with torch.no_grad():
            outputs = model(**encoded_inputs)
            predictions = torch.argmax(outputs.logits, dim=1).numpy()
        
        #add predictions to the batch DataFrame
        batch_df.loc[:, 'predicted_label'] = predictions
        results.append(batch_df[['Comment' if text_column == 'Comment' else 'Comment Body', 'predicted_label']])
        
        #save the batch to the output file
        #overwrite the first time, then append
        mode = 'w' if i == 0 else 'a'  
        #only write the header in the first batch
        header = (i == 0)  
        batch_df[['Comment' if text_column == 'Comment' else 'Comment Body', 'predicted_label']].to_csv(
            output_path, mode=mode, index=False, header=header
        )
        print(f"Batch {i // BATCH_SIZE + 1} processed and saved.")
    
    #return the full result as a dataframe 
    return pd.concat(results, ignore_index=True)

#run batch prediction for YouTube and Reddit comments
output_path_yt = "yt_comments_with_labels.csv"
output_path_red = "reddit_comments_with_labels.csv"

print("Processing YouTube comments in batches...")
youtube_results = predict_in_batches(youtube_comments_df, 'Comment', output_path_yt)

print("Processing Reddit comments in batches...")
reddit_results = predict_in_batches(reddit_comments_df, 'Comment Body', output_path_red)

print("All batches processed and saved.")
# Out:
# Processing YouTube comments in batches...
# /var/folders/w4/2kclbyfj3r18hk3f9t58c72c0000gn/T/ipykernel_672/2153933194.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch_df.loc[:, 'predicted_label'] = predictions
# Batch 1 processed and saved.
# /var/folders/w4/2kclbyfj3r18hk3f9t58c72c0000gn/T/ipykernel_672/2153933194.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch_df.loc[:, 'predicted_label'] = predictions
# Batch 2 processed and saved.
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

#load the CSV files
youtube_comments_df = pd.read_csv("/Users/siva/Downloads/kaggle_datasets/yt_comments_with_labels")
reddit_comments_df = pd.read_csv("/Users/siva/Downloads/kaggle_datasets/reddit_comments_with_labels")

labels_yt = youtube_comments_df['predicted_label'].values  
labels_red = reddit_comments_df['predicted_label'].values  

#calculate metrics for comments
accuracy_yt = accuracy_score(labels_yt, predictions_yt)
precision_yt = precision_score(labels_yt, predictions_yt, pos_label=1)
recall_yt = recall_score(labels_yt, predictions_yt, pos_label=1)
f1_yt = f1_score(labels_yt, predictions_yt, pos_label=1)
print("Comments Metrics:")
print(f"Accuracy: {accuracy_yt:.2f}")
print(f"Precision: {precision_yt:.2f}")
print(f"Recall: {recall_yt:.2f}")
print(f"F1 Score: {f1_yt:.2f}"

#calculate metrics for Reddit comments
#accuracy_red = accuracy_score(labels_red, predictions_red)
#precision_red = precision_score(labels_red, predictions_red, pos_label=1)
#recall_red = recall_score(labels_red, predictions_red, pos_label=1)
#f1_red = f1_score(labels_red, predictions_red, pos_label=1)
#print("\nReddit Comments Metrics:")
#print(f"Accuracy: {accuracy_red:.2f}")
#print(f"Precision: {precision_red:.2f}")
#print(f"Recall: {recall_red:.2f}")
#print(f"F1 Score: {f1_red:.2f}")

#alternatively, print the complete classification report
#print("\nClassification Report:")
#print(classification_report(labels_yt, predictions_yt, target_names=["Non-Hate", "Hate"]))

#print("\nReddit Comments Classification Report:")
#print(classification_report(labels_red, predictions_red, target_names=["Non-Hate", "Hate"]))
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
